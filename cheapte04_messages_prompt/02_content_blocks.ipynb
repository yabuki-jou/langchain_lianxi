# %% [markdown]
# #  1.content的使用

# %% [markdown]
# ## 1.1保存多模态列表

# %%
import base64
from langchain.chat_models import init_chat_model
from langchain.messages import HumanMessage
from dotenv import load_dotenv
import os

from langchain_openai import ChatOpenAI

load_dotenv(override=True)
model = init_chat_model(
    model="gpt-5.4-mini",
    model_provider="openai",
    api_key=os.getenv("OPENAI_API_KEY"),
    base_url=os.getenv("OPENAI_API_URL"),
    # model="deepseek-v4-flash",
    # model_provider="deepseek",
    # api_key=os.getenv("DEEPSEEK_API_KEY"),
    # base_url=os.getenv("DEEPSEEK_BASE_URL"),
)
def encode_image(img_path, img_type='jpeg'):
    """
    将一张本地图片转换成 Base64 编码的 Data URI 字符串,方便在文本中嵌入图片数据
    """
    with open(img_path, "rb") as img_file:
        return f"data:image/{img_type};base64,{base64.b64encode(img_file.read()).decode("utf-8")}"
# 图像路径
img_path = "image_test.png"
# 获取图像base64编码字符串
base64_image = encode_image(img_path)
response = model.invoke([
    HumanMessage(
        content=[
            {'type': 'text', 'text': '这张图里有什么？'},
            {
                'type': 'image_url',
                 "image_url": {
                    "url": base64_image
                 }
            }
        ]
    )
])
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[14], line 30
#      26 # 图像路径
#      27 img_path = "image_test.png"
#      28 # 获取图像base64编码字符串
#      29 base64_image = encode_image(img_path)
# ---> 30 response = model.invoke([
#      31     HumanMessage(
#      32         content=[
#      33             {'type': 'text', 'text': '这张图里有什么？'},
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\language_models\chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\language_models\chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\language_models\chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_core\language_models\chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_deepseek\chat_models.py:356, in ChatDeepSeek._generate(self, messages, stop, run_manager, **kwargs)
#     348 def _generate(
#     349     self,
#     350     messages: list[BaseMessage],
#    (...)    353     **kwargs: Any,
#     354 ) -> ChatResult:
#     355     try:
# --> 356         return super()._generate(
#     357             messages,
#     358             stop=stop,
#     359             run_manager=run_manager,
#     360             **kwargs,
#     361         )
#     362     except JSONDecodeError as e:
#     363         msg = (
#     364             "DeepSeek API returned an invalid response. "
#     365             "Please check the API status and try again."
#     366         )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_openai\chat_models\base.py:1490, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1488         response = raw_response.parse()
#    1489 except openai.BadRequestError as e:
# -> 1490     _handle_openai_bad_request(e)
#    1491 except openai.APIError as e:
#    1492     _handle_openai_api_error(e)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\langchain_openai\chat_models\base.py:1487, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1480         return _construct_lc_result_from_responses_api(
#    1481             response,
#    1482             schema=original_schema_obj,
#    1483             metadata=generation_info,
#    1484             output_version=self.output_version,
#    1485         )
#    1486     else:
# -> 1487         raw_response = self.client.with_raw_response.create(**payload)
#    1488         response = raw_response.parse()
#    1489 except openai.BadRequestError as e:
#
# File C:\D\Code\Langchain\langchain1.2\Lib\site-packages\openai\_legacy_response.py:367, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     363 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     365 kwargs["extra_headers"] = extra_headers
# --> 367 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File C:\D\Code\Langchain\langchain1.2\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File C:\D\Code\Langchain\langchain1.2\Lib\site-packages\openai\resources\chat\completions\completions.py:1251, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1203 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1204 def create(
#    1205     self,
#    (...)   1248     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1249 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1250     validate_response_format(response_format)
# -> 1251     return self._post(
#    1252         "/chat/completions",
#    1253         body=maybe_transform(
#    1254             {
#    1255                 "messages": messages,
#    1256                 "model": model,
#    1257                 "audio": audio,
#    1258                 "frequency_penalty": frequency_penalty,
#    1259                 "function_call": function_call,
#    1260                 "functions": functions,
#    1261                 "logit_bias": logit_bias,
#    1262                 "logprobs": logprobs,
#    1263                 "max_completion_tokens": max_completion_tokens,
#    1264                 "max_tokens": max_tokens,
#    1265                 "metadata": metadata,
#    1266                 "modalities": modalities,
#    1267                 "moderation": moderation,
#    1268                 "n": n,
#    1269                 "parallel_tool_calls": parallel_tool_calls,
#    1270                 "prediction": prediction,
#    1271                 "presence_penalty": presence_penalty,
#    1272                 "prompt_cache_key": prompt_cache_key,
#    1273                 "prompt_cache_retention": prompt_cache_retention,
#    1274                 "reasoning_effort": reasoning_effort,
#    1275                 "response_format": response_format,
#    1276                 "safety_identifier": safety_identifier,
#    1277                 "seed": seed,
#    1278                 "service_tier": service_tier,
#    1279                 "stop": stop,
#    1280                 "store": store,
#    1281                 "stream": stream,
#    1282                 "stream_options": stream_options,
#    1283                 "temperature": temperature,
#    1284                 "tool_choice": tool_choice,
#    1285                 "tools": tools,
#    1286                 "top_logprobs": top_logprobs,
#    1287                 "top_p": top_p,
#    1288                 "user": user,
#    1289                 "verbosity": verbosity,
#    1290                 "web_search_options": web_search_options,
#    1291             },
#    1292             completion_create_params.CompletionCreateParamsStreaming
#    1293             if stream
#    1294             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1295         ),
#    1296         options=make_request_options(
#    1297             extra_headers=extra_headers,
#    1298             extra_query=extra_query,
#    1299             extra_body=extra_body,
#    1300             timeout=timeout,
#    1301             security={"bearer_auth": True},
#    1302         ),
#    1303         cast_to=ChatCompletion,
#    1304         stream=stream or False,
#    1305         stream_cls=Stream[ChatCompletionChunk],
#    1306     )
#
# File C:\D\Code\Langchain\langchain1.2\Lib\site-packages\openai\_base_client.py:1332, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1323     warnings.warn(
#    1324         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1325         "Please pass raw bytes via the `content` parameter instead.",
#    1326         DeprecationWarning,
#    1327         stacklevel=2,
#    1328     )
#    1329 opts = FinalRequestOptions.construct(
#    1330     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331 )
# -> 1332 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File C:\D\Code\Langchain\langchain1.2\Lib\site-packages\openai\_base_client.py:1105, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1102             err.response.read()
#    1104         log.debug("Re-raising status error")
# -> 1105         raise self._make_status_error_from_response(err.response) from None
#    1107     break
#    1109 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'Failed to deserialize the JSON body into the target type: messages[0]: unknown variant `image_url`, expected `text` at line 1 column 37958', 'type': 'invalid_request_error', 'param': None, 'code': 'invalid_request_error'}}
