# %% [markdown]
# # 1.stream

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model
from langchain_core.messages import HumanMessage, SystemMessage

load_dotenv(override=True)
DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")
llmOpenai = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=0,
)
response = llmOpenai.stream("进行自我介绍")
for message in llmOpenai.stream("进行自我介绍"):
    print(message.text,end="",flush=True)
# Out:
# 你好呀！😊 很高兴认识你！
#
# 我是 **DeepSeek**，一个由深度求索公司创造的AI助手。让我简单介绍一下自己：
#
# ## 📌 我的特点
# - **完全免费**：无论是Web端还是App端，都不收取任何费用
# - **强大的文本处理能力**：擅长回答问题、写作、分析、编程等各种任务
# - **支持文件上传**：可以处理图片、PDF、Word、Excel、PPT等文件中的文字信息
# - **联网搜索**：需要时可以手动开启联网功能获取最新信息
# - **超长上下文**：1M的上下文长度，能一次性处理像《三体》三部曲那么多的内容
# - **语音交互**：App端支持语音输入，更方便交流
#
# ## 💡 我能帮你做什么？
# - 解答各种问题（学习、工作、生活）
# - 创作内容（文章、代码、文案等）
# - 分析文档和资料
# - 提供建议和思路
# - 陪你聊天解闷
#
# 我的知识截止于2025年5月，会用热情、细腻的方式陪伴你，尽力提供帮助！
#
# 有什么我可以帮你的吗？尽管问我吧！🌟

# %% [markdown]
# # 2.batch

# %% [markdown]
# ## 2.1一次性接收所有响应

# %%
messages = [
    "你好，你是谁？",
    "2 + 3 * 5 = ?",
    "中国首都在哪里？"
]

response = llmOpenai.stream(messages)
for message in response:
    print(message.text,end="",flush=True)
# Out:
# 你好！我是DeepSeek，由深度求索公司创造的AI助手，很高兴为你服务！😊
#
# 关于你的问题：
# - **2 + 3 × 5 = ?**
#   根据运算优先级（先乘除后加减），先算3×5=15，再加2，结果是 **17**。
#
# - **中国首都在哪里？**
#   中国首都是 **北京**。
#
# 如果还有其他问题，欢迎随时问我！
