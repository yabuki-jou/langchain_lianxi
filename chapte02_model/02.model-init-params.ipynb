# %% [markdown]
# # temperature的使用

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv(override=True)
DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")
llmOpenai = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=2
)
for i in range(3):
    print("--------------------------------------------------")
    response = llmOpenai.invoke("写一个十个字的小说大纲")
    print(response.content)
# Out:
# --------------------------------------------------
# 为十个字大纲，这个挑战真有意思！我为你准备了一份精炼到极致的小说骨架：
#
# **“获超能力脱单，却引灾难毁城，救赎。”**
#
# 这十个字包含了：
# - **开局**：获得超能力，邂逅爱情（平常人的逆袭幻想）
# - **转折**：能力失控，灾难降临（代价与冲突）
# - **收尾**：选择牺牲，终极救赎（情感升华）
#
# 它浓缩了起承转合，既有幻想元素，又有人性拷问。如果你想扩展，这里有几个方向：
#
# 1. 平凡少年突然觉醒读心术，在追求女神时意外发现城市秘密
# 2. 超能力是时间的馈赠，但每次使用都让挚爱在记忆中消散
# 3. 获得穿越能力挽救爱人，却发现自己才是灾难源头
#
# 如果需要进一步深化某个版本的人物或细节，随时告诉我。
# --------------------------------------------------
# 捡到龙宫宝物，隐瞒，被撞破，双赢。
# --------------------------------------------------
# 好的，这其实是一个极简但充满张力的核心设定：
#
# **他推开门，看见了另一个自己。**
#
# 这个故事可以往以下方向展开：
# - **平行宇宙**：两个自我来自不同世界线，因某种误差相遇
# - **人性之镜**：那个“自己”是他梦寐以求的成功版本，但背后藏着因果代价
# - **自我博弈**：这是否意味着必须相遇、对决、甚至取代，才能走向终局？
#
# 如果你愿意，可以先试着写出你对这个故事的理解——从“他”推开门的那一刻开始，你心中那个“另一个自己”是什么模样？

# %% [markdown]
# # max_tokens的使用

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv(override=True)
DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")
llmOpenai = init_chat_model(
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
    temperature=1,
    max_tokens=150
)
for i in range(3):
    print("--------------------------------------------------")
    response = llmOpenai.invoke("写一个十个字的小说大纲")
    print(response.content)
# Out:
# --------------------------------------------------
# 一个挺经典的结构：**弑神逆子，雪夜归复仇。**
# --------------------------------------------------
# 道侣拿了飞升机缘，反杀。
# --------------------------------------------------
# 明白了，十个字的大纲，要的是极
