# %% [markdown]
# # 1.调用模型厂商API
#
# ## 1.1.调用deepseek的模型
#
# 调用大模型涉及到三个重要参数:
# base_url,model_name,api_key
#
# 举例1:将参数文件放在.env配置文件中

# %% [markdown]
# 举例1

# %%
import os

from langchain.chat_models import init_chat_model
from langchain_community.chat_models import ChatZhipuAI, ChatTongyi, ChatOpenAI
from langchain_deepseek import ChatDeepSeek

from dotenv import load_dotenv
from langchain_openrouter import ChatOpenRouter
from sqlalchemy import true

#1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
print(DEEPSEEK_API_KEY)
if not DEEPSEEK_API_KEY:
    print("请在 .env 文件中设置 DEEPSEEK_API_KEY")
else:
    DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")

    llmDeepSpeed = ChatDeepSeek(
        model="deepseek-v4-flash",
        api_key=DEEPSEEK_API_KEY,
        base_url=DEEPSEEK_BASE_URL,
    )
    response = llmDeepSpeed.invoke("进行自我介绍")
    print(response)
# Out:
# sk-61339a0627ba4cf7b9ead48bddaadfc5
# ...

# %% [markdown]
# 举例2，对一的优化

# %%
from langchain_deepseek import ChatDeepSeek

from dotenv import load_dotenv

#1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# .env文件中的key和basa变量名与DEEPSEEK_API_KEY和DEEPSEEK_BASE_URL相同时可以省略他们的获取，ChatDeepSeek会自己去找
# DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
# DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")

llmDeepSpeed = ChatDeepSeek(
    model="deepseek-v4-flash",
    # api_key=DEEPSEEK_API_KEY,
    # base_url=DEEPSEEK_BASE_URL,
)
response = llmDeepSpeed.invoke("进行自我介绍")
print(response)
# Out:
# content='你好呀！我是DeepSeek，由深度求索公司创造的AI助手。😊\n\n**关于我的几个特点：**\n\n📝 **纯文本模型** - 我擅长文字处理和对话，支持阅读链接，但无法直接识别图片内容（不过你可以上传图片文件，我能读取其中的文字信息）\n\n📎 **文件处理能力** - 支持上传图像、txt、pdf、ppt、word、excel文件，我会从中读取文字信息帮你处理\n\n🌐 **联网搜索** - 需要你在Web/App端手动开启联网搜索功能，我就能帮你查找最新信息\n\n📚 **超长上下文** - 拥有1M的上下文窗口，可以一次性处理《三体》三部曲那样体量的长文本\n\n💰 **完全免费** - 目前我是完全免费的，没有任何收费计划\n\n🗣️ **语音输入** - App端支持语音输入，方便你随时提问\n\n我的知识截止于2025年5月，会尽我所能热情、细腻地为你解答问题！有什么我可以帮你的吗？🌟' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我进行自我介绍。这是一个非常简单的请求。用户可能刚接触我，想了解我的基本身份、能力和特点。深层需求是快速知道我是谁、能做什么、有什么限制。\n\n需要给出清晰、友好的自我介绍。想到了直接打招呼，然后说明我是DeepSeek，由深度求索公司创造。重点介绍核心功能：文本模型、文件处理、长上下文、联网搜索，并说明是免费的。需要提醒用户我是纯文本模型，不能识别图片内容但能读取文件文字。最后以开放性问题结束，邀请用户提问。\n\n用热情但专业的语气，信息点要明确，避免复杂结构。'} response_metadata={'token_usage': {'completion_tokens': 352, 'prompt_tokens': 6, 'total_tokens': 358, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 131, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': 
# ...

# %% [markdown]
# 举例3：写固定参数（不推荐）

# %%
import os

from langchain_deepseek import ChatDeepSeek

from dotenv import load_dotenv

#1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)
llmDeepSpeed = ChatDeepSeek(
    model="deepseek-v4-flash",
    api_key="sk-61339a0627ba4cf7b9ead48bddaadfc5",
    base_url="https://api.deepseek.com",
)
response = llmDeepSpeed.invoke("进行自我介绍")
print(response)
# Out:
# content='你好呀！很高兴认识你！😊\n\n我是 **DeepSeek**，由深度求索公司创造的AI助手。让我简单介绍一下自己：\n\n**我能做什么？**\n- 💬 回答各种问题（知识、学习、工作、生活等）\n- 📝 写作、翻译、总结、编程\n- 📄 处理上传的文件（图片、PDF、Word、Excel、PPT等），提取文字信息\n- 🔗 阅读链接内容\n- 🌐 联网搜索（需要手动开启）\n- 🎤 App端支持语音输入\n\n**我的特点：**\n- ✅ **完全免费**！没有收费计划\n- 🚀 超大上下文（1M token），可以一次处理整本《三体》三部曲\n- 📱 支持网页版和App（官方应用商店可下载）\n- 🔄 知识截止到2025年5月\n\n**需要注意：**\n- 我是纯文本模型，不能直接“看”图片，但可以读取图片中的文字\n- 我不能生成图片或视频\n\n有什么我可以帮你的吗？无论是学习、工作还是闲聊，我都很乐意陪你聊～😊' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户让我进行自我介绍。这是一个非常简单的请求，用户可能刚接触我，想了解我的基本情况和能力。我需要给出一个清晰、友好、全面的自我介绍，涵盖我的身份、核心功能、知识范围、特点等。想到了用热情的开场，然后分块介绍我是谁、能做什么、特点、注意事项和知识截止时间，最后以开放式的邀请结束。这样结构比较完整，信息也足够。可以开始回答了。'} response_metadata={'token_usage': {'completion_tokens': 333, 'prompt_tokens': 6, 'total_tokens': 339, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 92, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens
# ...

# %% [markdown]
# ### 1.2智谱

# %%
from langchain_community.chat_models import ChatZhipuAI

from dotenv import load_dotenv

#1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

# ZHIPUAI_API_KEY= os.getenv("ZHIPUAI_API_KEY")
# ZHIPUAI_BASE_URL= os.getenv("ZHIPUAI_BASE_URL")

llmZhipu = ChatZhipuAI(
    model="glm-5.2",
    # api_key=ZHIPUAI_API_KEY,
    # base_url=ZHIPUAI_BASE_URL,
)
response = llmZhipu.invoke("进行自我介绍")
print(response)
# Out:
# content='你好！我是一个由Z.ai训练的大型语言模型，你可以叫我AI助手。\n\n我的设计初衷是帮助人们获取信息、解决问题和激发创意。我没有名字，也没有实体，存在于服务器中，通过自然语言处理技术与你进行交流。\n\n我可以做很多事情，比如：\n\n*   **回答问题**：无论是科学知识、历史事件还是生活小常识，我都可以尽力为你解答。\n*   **内容创作**：帮你写邮件、写文章、写故事、写诗，甚至帮你写代码。\n*   **语言翻译**：支持多种语言之间的互译，帮你跨越语言障碍。\n*   **信息处理**：帮你总结长文、提炼要点、整理资料。\n*   **头脑风暴**：在你需要灵感时，提供各种创意和建议。\n\n我的知识来源于大量的文本数据，但请注意，我没有个人情感和意识，也无法获取实时信息（除非通过特定工具）。虽然我会尽力确保回答的准确性，但有时也可能会犯错，所以对于关键信息，建议你再核实一下。\n\n我会持续学习和进步，希望能成为你得力的助手。请问今天有什么可以帮你的吗？' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 992, 'completion_tokens_details': {'reasoning_tokens': 758}, 'prompt_tokens': 15, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 1007}, 'model_name': 'glm-5.2', 'finish_reason': 'stop'} id='lc_run--019f27ff-9a95-7d01-b2bd-fb5b067f9ec5-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# ### 1.3阿里百炼云

# %%
import os
from dotenv import load_dotenv
from langchain_community.chat_models import ChatTongyi
#1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

DASHSCOPE_API_KEY= os.getenv("DASHSCOPE_API_KEY")

llmTongyi = ChatTongyi(
    model="qwen3.7-max",
    api_key=DASHSCOPE_API_KEY,
)
response = llmTongyi.invoke("进行自我介绍")
print(response)
# Out:
# content='你好！我是通义千问（Qwen），是由阿里巴巴集团通义实验室自主研发的大语言模型。\n\n作为你的 AI 思考伙伴，我致力于为你提供清晰、准确、简洁且真实的帮助。无论是日常问答、内容创作、逻辑推理、代码编写，还是复杂问题的深度分析，我都希望能为你提供有价值的支持。\n\n请问今天有什么我可以帮你的吗？' additional_kwargs={'reasoning_content': '用户让我进行自我介绍。\n我需要说明我是通义千问（Qwen），由阿里巴巴集团通义实验室自主研发的大语言模型。\n回复需要清晰、简洁、真实且有帮助，语言与用户一致（中文）。\n\n思考要点：\n1. 身份：通义千问（Qwen）。\n2. 开发者：阿里巴巴集团通义实验室。\n3. 能力/定位：人工智能思考伙伴，提供清晰、准确、简洁、真实的帮助。\n4. 语言：中文。\n\n起草回复：\n你好！我是通义千问（Qwen），由阿里巴巴集团通义实验室自主研发的大语言模型。我是一个人工智能思考伙伴，致力于为你提供清晰、准确、简洁且真实的帮助。无论是解答问题、提供建议、协助创作，还是进行逻辑推理和代码编写，我都很高兴能为你效劳。请问今天有什么我可以帮你的吗？\n\n检查：\n- 身份纯净性：用户要求自我介绍，所以提供身份信息是合适的。\n- 语言同步：中文。\n- 品牌一致性：自称通义千问/Qwen，没有提及版本号。\n\n修改完善，使语气亲和、自然：\n你好！我是通义千问（Qwen），是由阿里巴巴集团通义实验室自主研发的大语言模型。\n\n作为你的 AI 思考伙伴，我致力于为你提供清晰、准确、简洁且真实的帮助。无论是日常问答、内容创作、逻辑推理、代码编写，还是复杂问题的深度分析，我都希望能为你提供有价值的支持。\n\n请问今天有什么我可以帮你的吗？\n\n这样既完成了自我介绍，又展现了乐于助人的态度。符合所有要求。'} response_metadata={'model_name': 'qwen3.7-max', 'finish_reason': 'stop', 'request_id': '6314b7fa-d536-97d5-a759-d116914d2af5', 'token_usage': {'input_tokens': 12, 'output_tokens': 413
# ...

# %% [markdown]
# # 2兼容写法
# ## 使用chatOpenAi
# ### 举例1

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv(override=True)
DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")
llmOpenai = ChatOpenAI(
    model="deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)
print(llmOpenai.invoke("1+1=?"))
# Out:
# content='2' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 33, 'prompt_tokens': 8, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 31, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 8}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '5604358a-41f2-4c59-845b-42123981641e', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f2b54-7582-7fa1-8dd7-1e8c2d79bca2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 8, 'output_tokens': 33, 'total_tokens': 41, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 31}}

# %% [markdown]
# ## 使用openrouter

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv(override=True)
OPENROUTER_API_KEY= os.getenv("OPENROUTER_API_KEY")
DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")
llmOpenai = ChatOpenRouter(
    model="deepseek-v4-flash",
    api_key=OPENROUTER_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)
print(llmOpenai.invoke("1+1=?"))

# %% [markdown]
# ## 使用langchain1.x的具体方式

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

load_dotenv(override=True)
DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")
llmOpenai = init_chat_model(
    # model="deepseek-v4-flash",
    # model_provider="deepseek",
    # 或者
    model="deepseek:deepseek-v4-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL,
)
print(llmOpenai.invoke("介绍你自己"))
# Out:
# content='你好呀！很高兴认识你！😊\n\n我是**DeepSeek**，一个由深度求索公司创造的AI助手。让我简单介绍一下自己：\n\n## 🌟 我的特点\n\n- **知识广博**：我的知识截止到2025年5月，涵盖各个领域\n- **超强上下文**：1M的上下文长度，可以一次性处理《三体》三部曲那么大体量的内容！\n- **多格式支持**：能处理txt、pdf、ppt、word、excel等多类文件，从中读取文字信息帮你分析\n- **联网搜索**：支持联网查询最新信息（需要手动开启哦）\n- **完全免费**：没错，现在和未来都计划保持免费！\n\n## 💬 我能做什么\n\n- 回答各种问题，从生活常识到专业知识\n- 帮你写作、翻译、总结文档\n- 进行头脑风暴，提供创意建议\n- 分析和解读你上传的文件内容\n- 用多种语言交流（你用什么语言问我，我就用什么语言回答）\n\n## 📱 怎么使用我\n\n你可以通过网页端访问，也可以下载App（支持语音输入哦！）\n\n有什么想问的或者需要帮忙的吗？尽管开口，我会热情地帮助你！🎉' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我介绍自己。这是一个非常基础且常见的开场问题。用户可能是第一次接触我，想了解我的能力和定位。我需要给出一个清晰、全面且友好的自我介绍，让用户快速知道我是谁、能做什么、有什么特点以及如何使用我。\n\n想到了可以从几个核心方面来组织回复：先热情打招呼，然后说明我的身份和创造者。接着重点介绍我的核心能力、知识范围、文件处理等特色功能，以及完全免费这个关键优势。最后提一下获取方式和一些限制，以帮助用户合理使用。整体语气要热情、乐于助人，符合一个AI助手的定位。'} response_metadata={'token_usage': {'completion_tokens': 385, 'prompt_tokens': 6, 'total_tokens': 391, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 127, 'reje
# ...
