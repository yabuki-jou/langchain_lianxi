# %% [markdown]
# # 1.调用模型厂商API
#
# ## 1.1.调用deepseek的模型
#
# 调用大模型涉及到三个重要参数:
# base_url,model_name,api_key
#
# 举例1:将参数文件放在.env配置文件中

# %%
import os

from langchain_deepseek import ChatDeepSeek

from dotenv import load_dotenv

#1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
print(DEEPSEEK_API_KEY)
if not DEEPSEEK_API_KEY:
    print("请在 .env 文件中设置 DEEPSEEK_API_KEY")
else:
    DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")

    llmDeepSpeed = ChatDeepSeek(
        model="deepseek-v4-flash",
        api_key=DEEPSEEK_API_KEY,
        base_url=DEEPSEEK_BASE_URL,
    )
    response = llmDeepSpeed.invoke("进行自我介绍")
    print(response)
# Out:
# C:\Users\失吹丈\AppData\Local\Temp\ipykernel_37360\1409644867.py:6: DeprecationWarning: numpy.core is deprecated and has been renamed to numpy._core. The numpy._core namespace contains private NumPy internals and its use is discouraged, as NumPy internals can change without warning in any release. In practice, most real-world usage of numpy.core is to access functionality in the public NumPy API. If that is the case, use the public NumPy API. If not, you are using NumPy internals. If you would still like to access an internal attribute, use numpy._core.overrides.
#   from numpy.core import overrides
# sk-61339a0627ba4cf7b9ead48bddaadfc5
# content='你好！我是 **DeepSeek**，由深度求索公司创造的AI助手。很高兴认识你！😊\n\n让我简单介绍一下自己：\n\n### 🌟 我的特点\n- **完全免费**：无论是网页版还是App，都不收取任何费用\n- **超长上下文**：支持1M token的上下文理解，可以一次性处理像《三体》三部曲这样体量的书籍\n- **多文件支持**：可以处理图像、PDF、Word、Excel、PPT、TXT等多种文件格式\n- **联网搜索**：支持联网查询最新信息（需要手动开启）\n- **语音输入**：App端支持语音交互\n\n### 💬 我能帮你做什么？\n- 回答各种问题（知识、学习、生活等）\n- 创作内容（写作、翻译、编程等）\n- 分析文档（总结、提取信息等）\n- 头脑风暴和创意讨论\n- 日常交流陪伴\n\n### 📱 如何使用我？\n你可以通过官方应用商店下载App，或在网页端直接使用。\n\n有什么我可以帮你的吗？无论是学习、工作还是日常闲聊，我都很乐意和你交流！✨' additional_kwargs={'refusal': None, 'reasoning_content': '嗯，用户让我做自我介绍。这是一个非常直接和常见的请求。我需要明确自己的身份和功能，然后清晰地、有条理地向用户介绍自己。考虑到用户可能是在初次接触，介绍应该友好、热情，并突出核心能力和可用性。想到了可以从几个方面组织回复：先问候并表明身份，然后说明我是谁、由谁开发，接着列举主要功能特点，比如文本处理能力、上下文长度、文件处理、联网搜索等，最后说明如何访问和使用，并以一个开放性的提问结束，邀请用户提出具体需求。整体语气要亲切、有帮助性。'} response_metadata={'token_usage': {'completion_tokens': 359, 'prompt_tokens': 6, 'total_tokens': 365, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 121, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '22f76eae-1d38-4422-8026-bf1c06059318', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f2777-d9bf-74e0-ae2c-b626d38dd031-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 359, 'total_tokens': 365, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 121}}
