# %% [markdown]
# # 1.调用模型厂商API
#
# ## 1.1.调用deepseek的模型
#
# 调用大模型涉及到三个重要参数:
# base_url,model_name,api_key
#
# 举例1:将参数文件放在.env配置文件中

# %%
import os

from langchain_deepseek import ChatDeepSeek

from dotenv import load_dotenv

#1、读取.env配置文件中的信息。相关的环境变量以.env文件中的优先
load_dotenv(override=True)

DEEPSEEK_API_KEY= os.getenv("DEEPSEEK_API_KEY")
print(DEEPSEEK_API_KEY)
if not DEEPSEEK_API_KEY:
    print("请在 .env 文件中设置 DEEPSEEK_API_KEY")
else:
    DEEPSEEK_BASE_URL= os.getenv("DEEPSEEK_BASE_URL")

    llmDeepSpeed = ChatDeepSeek(
        model="deepseek-v4-flash",
        api_key=DEEPSEEK_API_KEY,
        base_url=DEEPSEEK_BASE_URL,
    )
    response = llmDeepSpeed.invoke("进行自我介绍")
    print(response)
# Out:
# sk-61339a0627ba4cf7b9ead48bddaadfc5
# content='你好呀！很高兴认识你！🤗\n\n我是**DeepSeek**，由深度求索公司创造的AI助手。让我给你介绍一下我的“超能力”：\n\n**我的特点：**\n- 📚 **知识储备**：知识截止到2025年5月，能回答各种领域的问题\n- 💬 **纯文本专家**：擅长文字对话、写作、翻译、编程等等\n- 📎 **文件处理**：支持上传图片、PDF、Word、Excel、PPT等文件，能从中提取文字信息\n- 🌐 **联网搜索**：需要时可以帮你搜索最新信息（你得手动开启哦）\n- 💪 **超大容量**：上下文1M，能一次性处理《三体》三部曲那么多内容！\n- 🆓 **完全免费**：没错，我是免费的！而且App端还支持语音输入\n\n**我不能做的：**\n- ❌ 不支持图像识别（虽然能读图片里的文字）\n- ❌ 不能生成图片或视频\n\n无论是学习、工作、编程还是日常聊天，我都乐意帮忙！有什么想问的或者需要帮助的吗？我随时待命！😊' additional_kwargs={'refusal': None, 'reasoning_content': '好的，用户让我进行自我介绍。这是一个非常简单的请求。我需要明确自己的身份和功能，让用户快速了解我能做什么、有什么特点。想到了可以介绍我的核心能力，比如文本处理、文件支持、免费使用等关键信息。用友好、热情的语气开头，然后分点说明，但思考过程中不需要列出，只需想清楚要涵盖哪些要点：名称、创造者、能力范围（文字、文件、联网等）、上下文长度、强调免费，最后以开放式的邀请结束。保持信息准确、清晰、有吸引力。'} response_metadata={'token_usage': {'completion_tokens': 349, 'prompt_tokens': 6, 'total_tokens': 355, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 112, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 6}, 'model_provider': 'deepseek', 'model_name': 'deepseek-v4-flash', 'system_fingerprint': 'fp_8b330d02d0_prod0820_fp8_kvcache_20260402', 'id': '24214484-53ca-44e2-924d-88bcebc5c721', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--019f2782-ce1b-7db3-bef8-277cfbf71be2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 6, 'output_tokens': 349, 'total_tokens': 355, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 112}}
